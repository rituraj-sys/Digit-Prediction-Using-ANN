# %%
import numpy as np
import pandas as pd

# %%
from tensorflow import keras
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense, Flatten

# %%
(x_train,y_train),(x_test,y_test) = keras.datasets.mnist.load_data()

# %%
x_train.shape,x_test.shape
# Out:
# ((60000, 28, 28), (10000, 28, 28))

# %%
x_train = x_train/255
x_test = x_test/2555

# %%
model = Sequential()
model.add(Flatten(input_shape = (28,28)))
model.add(Dense(132,activation = 'relu'))
model.add(Dense(10,activation = 'softmax'))

# %%
model.compile(loss = 'sparse_categorical_crossentropy',optimizer = 'Adam',metrics = ['accuracy'])

# %%
history = model.fit(x_train,y_train,epochs = 28,validation_split = 0.2)
# Out:
# Epoch 1/28
# 1500/1500 [==============================] - 9s 6ms/step - loss: 0.2844 - accuracy: 0.9194 - val_loss: 0.1586 - val_accuracy: 0.9541
# Epoch 2/28
# 1500/1500 [==============================] - 12s 8ms/step - loss: 0.1231 - accuracy: 0.9641 - val_loss: 0.1093 - val_accuracy: 0.9669
# Epoch 3/28
# 1500/1500 [==============================] - 10s 6ms/step - loss: 0.0830 - accuracy: 0.9752 - val_loss: 0.0933 - val_accuracy: 0.9712
# Epoch 4/28
# 1500/1500 [==============================] - 7s 5ms/step - loss: 0.0613 - accuracy: 0.9819 - val_loss: 0.0923 - val_accuracy: 0.9715
# Epoch 5/28
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.0465 - accuracy: 0.9858 - val_loss: 0.0877 - val_accuracy: 0.9729
# Epoch 6/28
# 1500/1500 [==============================] - 7s 5ms/step - loss: 0.0367 - accuracy: 0.9892 - val_loss: 0.0848 - val_accuracy: 0.9744
# Epoch 7/28
# 1500/1500 [==============================] - 7s 5ms/step - loss: 0.0274 - accuracy: 0.9918 - val_loss: 0.0840 - val_accuracy: 0.9751
# Epoch 8/28
# 1500/1500 [==============================] - 8s 5ms/step - loss: 0.0230 - accuracy: 0.9932 - val_loss: 0.0876 - val_accuracy: 0.9739
# Epoch 9/28
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.0189 - accuracy: 0.9945 - val_loss: 0.0871 - val_accuracy: 0.9767
# Epoch 10/28
# 1500/1500 [==============================] - 7s 5ms/step - loss: 0.0148 - accuracy: 0.9954 - val_loss: 0.0963 - val_accuracy: 0.9752
# Epoch 11/28
# 1500/1500 [==============================] - 7s 5ms/step - loss: 0.0127 - accuracy: 0.9963 - val_loss: 0.0957 - val_accuracy: 0.9759
# Epoch 12/28
# 1500/1500 [==============================] - 13s 8ms/step - loss: 0.0112 - accuracy: 0.9965 - val_loss: 0.1170 - val_accuracy: 0.9705
# Epoch 13/28
# 1500/1500 [==============================] - 11s 8ms/step - loss: 0.0098 - accuracy: 0.9970 - val_loss: 0.1013 - val_accuracy: 0.9758
# Epoch 14/28
# 1500/1500 [==============================] - 9s 6ms/step - loss: 0.0066 - accuracy: 0.9984 - val_loss: 0.1033 - val_accuracy: 0.9758
# Epoch 15/28
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.0092 - accuracy: 0.9971 - val_loss: 0.1010 - val_accuracy: 0.9780
# Epoch 16/28
# 1500/1500 [==============================] - 8s 5ms/step - loss: 0.0058 - accuracy: 0.9983 - val_loss: 0.1176 - val_accuracy: 0.9747
# Epoch 17/28
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.0059 - accuracy: 0.9981 - val_loss: 0.1122 - val_accuracy: 0.9771
# Epoch 18/28
# 1500/1500 [==============================] - 7s 5ms/step - loss: 0.0051 - accuracy: 0.9985 - val_loss: 0.1157 - val_accuracy: 0.9774
# Epoch 19/28
# 1500/1500 [==============================] - 7s 4ms/step - loss: 0.0058 - accuracy: 0.9982 - val_loss: 0.1195 - val_accuracy: 0.9751
# Epoch 20/28
# 1500/1500 [==============================] - 8s 5ms/step - loss: 0.0053 - accuracy: 0.9984 - val_loss: 0.1198 - val_accuracy: 0.9772
# Epoch 21/28
# 1500/1500 [==============================] - 8s 5ms/step - loss: 0.0048 - accuracy: 0.9981 - val_loss: 0.1243 - val_accuracy: 0.9762
# Epoch 22/28
# 1500/1500 [==============================] - 7s 4ms/step - loss: 0.0041 - accuracy: 0.9986 - val_loss: 0.1339 - val_accuracy: 0.9773
# Epoch 23/28
# 1500/1500 [==============================] - 8s 5ms/step - loss: 0.0035 - accuracy: 0.9990 - val_loss: 0.1287 - val_accuracy: 0.9753
# Epoch 24/28
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.0043 - accuracy: 0.9985 - val_loss: 0.1319 - val_accuracy: 0.9772
# Epoch 25/28
# 1500/1500 [==============================] - 8s 5ms/step - loss: 0.0038 - accuracy: 0.9989 - val_loss: 0.1258 - val_accuracy: 0.9781
# Epoch 26/28
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.0015 - accuracy: 0.9997 - val_loss: 0.1211 - val_accuracy: 0.9779
# Epoch 27/28
# 1500/1500 [==============================] - 8s 5ms/step - loss: 0.0060 - accuracy: 0.9979 - val_loss: 0.1264 - val_accuracy: 0.9782
# Epoch 28/28
# 1500/1500 [==============================] - 7s 5ms/step - loss: 0.0012 - accuracy: 0.9996 - val_loss: 0.1378 - val_accuracy: 0.9771

# %%
y_prob = model.predict(x_test)
# Out:
# 313/313 [==============================] - 1s 2ms/step

# %%
y_pred = y_prob.argmax(axis = 1)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_pred,y_test)
# Out:
# 0.9199

# %%
import matplotlib.pyplot as plt
plt.imshow(x_train[0])

# %%
y_train[0]
# Out:
# 5

# %%
history.history
# Out:
# {'loss': [0.2844274044036865,
#   0.12309145927429199,
#   0.0829746425151825,
#   0.0613020583987236,
#   0.046498581767082214,
#   0.03671353682875633,
#   0.02742270939052105,
#   0.02302604913711548,
#   0.018939154222607613,
#   0.014777937904000282,
#   0.012716756202280521,
#   0.011237110011279583,
#   0.009767833165824413,
#   0.006578484084457159,
#   0.009219609200954437,
#   0.0058023352175951,
#   0.005925863981246948,
#   0.005101073067635298,
#   0.005831543821841478,
#   0.005339848808944225,
#   0.004802876617759466,
#   0.004082499071955681,
#   0.0035217173863202333,
#   0.004315728321671486,
#   0.003804091364145279,
#   0.0015401393175125122,
#   0.0059544481337070465,
#   0.0012327063595876098],
#  'accuracy': [0.9194375276565552,
#   0.9641249775886536,
#   0.9752083420753479,
#   0.9819375276565552,
#   0.9858124852180481,
#   0.9892083406448364,
#   0.9917500019073486,
#   0.9931874871253967,
#   0.9944583177566528,
#   0.995395839214325,
#   0.9962916374206543,
#   0.9965208172798157,
#   0.9969791769981384,
#   0.9983541369438171,
#   0.9971041679382324,
#   0.9983124732971191,
#   0.9980624914169312,
#   0.9984791874885559,
#   0.9982083439826965,
#   0.9983749985694885,
#   0.9981458187103271,
#   0.9985833168029785,
#   0.9989583492279053,
#   0.9985208511352539,
#   0.9988750219345093,
#   0.9997291564941406,
#   0.9978958368301392,
#   0.9996458292007446],
#  'val_loss': [0.15861859917640686,
#   0.1093476340174675,
#   0.09325556457042694,
#   0.09226997196674347,
#   0.08770930767059326,
#   0.08475100249052048,
#   0.08402906358242035,
#   0.08755604177713394,
#   0.08712922036647797,
#   0.09631366282701492,
#   0.09572102874517441,
#   0.11700751632452011,
#   0.10131588578224182,
#   0.10333371162414551,
#   0.10104881972074509,
#   0.11759760230779648,
#   0.11216320097446442,
#   0.11569693684577942,
#   0.11951491981744766,
#   0.11980457603931427,
#   0.12427432090044022,
#   0.1338604837656021,
#   0.12871792912483215,
#   0.1318884640932083,
#   0.1257551908493042,
#   0.12111268937587738,
#   0.1263514757156372,
#   0.13781483471393585],
#  'val_accuracy': [0.9540833234786987,
#   0.9669166803359985,
#   0.9712499976158142,
#   0.9714999794960022,
#   0.9729166626930237,
#   0.9744166731834412,
#   0.9750833511352539,
#   0.9739166498184204,
#   0.9766666889190674,
#   0.9751666784286499,
#   0.9759166836738586,
#   0.9704999923706055,
#   0.9757500290870667,
#   0.9757500290870667,
#   0.9779999852180481,
#   0.9747499823570251,
#   0.9770833253860474,
#   0.9774166941642761,
#   0.9750833511352539,
#   0.9772499799728394,
#   0.9762499928474426,
#   0.9773333072662354,
#   0.9753333330154419,
#   0.9771666526794434,
#   0.9780833125114441,
#   0.9779166579246521,
#   0.9781666398048401,
#   0.9770833253860474]}

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_accuracy'])

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])

# %%
y_pred[9999],y_test[9999]
# Out:
# (6, 6)

# %%
plt.imshow(x_test[9999])
